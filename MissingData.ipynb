# %%
import pandas as pd
import numpy as np

# %%
data = {
    "name": ["Utsav", "Rahul", "Priya", "Aman", "Sneha", "Rohit", "Neha", "Vikash"],
    "age": [22, 24, np.nan, 25, 23, np.nan, 22, 24],
    "gender": ["Male", "Male", "Female", "Male", np.nan, "Male", "Female", "Male"],
    "city": ["Bhopal", "Delhi", "Mumbai", np.nan, "Indore", "Pune", "Jaipur", "Bangalore"],
    "salary": [45000, np.nan, 40000, 65000, np.nan, 70000, 52000, 60000]
}

df = pd.DataFrame(data)
df
# Out:
#      name   age  gender       city   salary
# 0   Utsav  22.0    Male     Bhopal  45000.0
# 1   Rahul  24.0    Male      Delhi      NaN
# 2   Priya   NaN  Female     Mumbai  40000.0
# 3    Aman  25.0    Male        NaN  65000.0
# 4   Sneha  23.0     NaN     Indore      NaN
# 5   Rohit   NaN    Male       Pune  70000.0
# 6    Neha  22.0  Female     Jaipur  52000.0
# 7  Vikash  24.0    Male  Bangalore  60000.0

# %%
df.isna()
# Out:
#     name    age  gender   city  salary
# 0  False  False   False  False   False
# 1  False  False   False  False    True
# 2  False   True   False  False   False
# 3  False  False   False   True   False
# 4  False  False    True  False    True
# 5  False   True   False  False   False
# 6  False  False   False  False   False
# 7  False  False   False  False   False

# %%
df.isna().sum()
# Out:
# name      0
# age       2
# gender    1
# city      1
# salary    2
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(6)

# %%
df.dropna()
# Out:
#      name   age  gender       city   salary
# 0   Utsav  22.0    Male     Bhopal  45000.0
# 6    Neha  22.0  Female     Jaipur  52000.0
# 7  Vikash  24.0    Male  Bangalore  60000.0

# %%
df
# Out:
#      name   age  gender       city   salary
# 0   Utsav  22.0    Male     Bhopal  45000.0
# 1   Rahul  24.0    Male      Delhi      NaN
# 2   Priya   NaN  Female     Mumbai  40000.0
# 3    Aman  25.0    Male        NaN  65000.0
# 4   Sneha  23.0     NaN     Indore      NaN
# 5   Rohit   NaN    Male       Pune  70000.0
# 6    Neha  22.0  Female     Jaipur  52000.0
# 7  Vikash  24.0    Male  Bangalore  60000.0

# %%
df.dropna(axis=1)
# Out:
#      name
# 0   Utsav
# 1   Rahul
# 2   Priya
# 3    Aman
# 4   Sneha
# 5   Rohit
# 6    Neha
# 7  Vikash

# %%
df
# Out:
#      name   age  gender       city   salary
# 0   Utsav  22.0    Male     Bhopal  45000.0
# 1   Rahul  24.0    Male      Delhi      NaN
# 2   Priya   NaN  Female     Mumbai  40000.0
# 3    Aman  25.0    Male        NaN  65000.0
# 4   Sneha  23.0     NaN     Indore      NaN
# 5   Rohit   NaN    Male       Pune  70000.0
# 6    Neha  22.0  Female     Jaipur  52000.0
# 7  Vikash  24.0    Male  Bangalore  60000.0

# %%
df.fill(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.fill(0)
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'fill'

# %%
df.fillna(0)
# Out:
#      name   age  gender       city   salary
# 0   Utsav  22.0    Male     Bhopal  45000.0
# 1   Rahul  24.0    Male      Delhi      0.0
# 2   Priya   0.0  Female     Mumbai  40000.0
# 3    Aman  25.0    Male          0  65000.0
# 4   Sneha  23.0       0     Indore      0.0
# 5   Rohit   0.0    Male       Pune  70000.0
# 6    Neha  22.0  Female     Jaipur  52000.0
# 7  Vikash  24.0    Male  Bangalore  60000.0

# %%
df["salary"]=df["salary"].fillna(df["salary"].mean())
df
# Out:
#      name   age  gender       city        salary
# 0   Utsav  22.0    Male     Bhopal  45000.000000
# 1   Rahul  24.0    Male      Delhi  55333.333333
# 2   Priya   NaN  Female     Mumbai  40000.000000
# 3    Aman  25.0    Male        NaN  65000.000000
# 4   Sneha  23.0     NaN     Indore  55333.333333
# 5   Rohit   NaN    Male       Pune  70000.000000
# 6    Neha  22.0  Female     Jaipur  52000.000000
# 7  Vikash  24.0    Male  Bangalore  60000.000000

# %%
df["age"]=df["age"].fillna(df["age"].mean())
df
# Out:
#      name        age  gender       city        salary
# 0   Utsav  22.000000    Male     Bhopal  45000.000000
# 1   Rahul  24.000000    Male      Delhi  55333.333333
# 2   Priya  23.333333  Female     Mumbai  40000.000000
# 3    Aman  25.000000    Male        NaN  65000.000000
# 4   Sneha  23.000000     NaN     Indore  55333.333333
# 5   Rohit  23.333333    Male       Pune  70000.000000
# 6    Neha  22.000000  Female     Jaipur  52000.000000
# 7  Vikash  24.000000    Male  Bangalore  60000.000000
