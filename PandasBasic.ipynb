# %%
import numpy as np
import pandas as pd

# %%
data = {
    "name": ["Utsav", "Rahul", "Priya", "Aman", "Sneha", "Rohit", "Neha", "Vikash"],
    "age": [22, 24, 21, 25, 23, 26, 22, 24],
    "city": ["Bhopal", "Delhi", "Mumbai", "Patna", "Indore", "Patna", "Jaipur", "Bangalore"],
    "salary": [45000, 55000, 40000, 65000, 48000, 70000, 52000, 60000]
}
pd.Series(data)
# Out:
# name      [Utsav, Rahul, Priya, Aman, Sneha, Rohit, Neha...
# age                        [22, 24, 21, 25, 23, 26, 22, 24]
# city      [Bhopal, Delhi, Mumbai, Patna, Indore, Patna, ...
# salary    [45000, 55000, 40000, 65000, 48000, 70000, 520...
# dtype: object

# %%
df=pd.DataFrame(data)
df
# Out:
#      name  age       city  salary
# 0   Utsav   22     Bhopal   45000
# 1   Rahul   24      Delhi   55000
# 2   Priya   21     Mumbai   40000
# 3    Aman   25      Patna   65000
# 4   Sneha   23     Indore   48000
# 5   Rohit   26      Patna   70000
# 6    Neha   22     Jaipur   52000
# 7  Vikash   24  Bangalore   60000

# %%
#Selecting col.
df["name"]
# Out:
# 0     Utsav
# 1     Rahul
# 2     Priya
# 3      Aman
# 4     Sneha
# 5     Rohit
# 6      Neha
# 7    Vikash
# Name: name, dtype: str

# %%
#selecting multiple col.
df[["name","city"]]
# Out:
#      name       city
# 0   Utsav     Bhopal
# 1   Rahul      Delhi
# 2   Priya     Mumbai
# 3    Aman      Patna
# 4   Sneha     Indore
# 5   Rohit      Patna
# 6    Neha     Jaipur
# 7  Vikash  Bangalore

# %%
#Adding another coll.
df["Gender"]=["Male", "Male", "Female", "Male", "Female", "Male", "Female", "Male"]

# %%
df
# Out:
#      name  age       city  salary  Gender
# 0   Utsav   22     Bhopal   45000    Male
# 1   Rahul   24      Delhi   55000    Male
# 2   Priya   21     Mumbai   40000  Female
# 3    Aman   25      Patna   65000    Male
# 4   Sneha   23     Indore   48000  Female
# 5   Rohit   26      Patna   70000    Male
# 6    Neha   22     Jaipur   52000  Female
# 7  Vikash   24  Bangalore   60000    Male

# %%
#Deleting col.
df.drop("Gender",axis=1,inplace=True)
df
# Out:
#      name  age       city  salary
# 0   Utsav   22     Bhopal   45000
# 1   Rahul   24      Delhi   55000
# 2   Priya   21     Mumbai   40000
# 3    Aman   25      Patna   65000
# 4   Sneha   23     Indore   48000
# 5   Rohit   26      Patna   70000
# 6    Neha   22     Jaipur   52000
# 7  Vikash   24  Bangalore   60000

# %%
df
# Out:
#      name  age       city  salary
# 0   Utsav   22     Bhopal   45000
# 1   Rahul   24      Delhi   55000
# 2   Priya   21     Mumbai   40000
# 3    Aman   25      Patna   65000
# 4   Sneha   23     Indore   48000
# 5   Rohit   26      Patna   70000
# 6    Neha   22     Jaipur   52000
# 7  Vikash   24  Bangalore   60000

# %%
#Selecting the row
df.loc[0]
# Out:
# name       Utsav
# age           22
# city      Bhopal
# salary     45000
# Name: 0, dtype: object

# %%
#Selecting multiple rows 
df.loc[[2,3]]
# Out:
#     name  age    city  salary
# 2  Priya   21  Mumbai   40000
# 3   Aman   25   Patna   65000

# %%
df.loc[[5,6]][["name","age","city"]]
# Out:
#     name  age    city
# 5  Rohit   26   Patna
# 6   Neha   22  Jaipur

# %%
#Conditional statement
#People with age above 23
df[df["age"] >= 23]
# Out:
#      name  age       city  salary
# 1   Rahul   24      Delhi   55000
# 3    Aman   25      Patna   65000
# 4   Sneha   23     Indore   48000
# 5   Rohit   26      Patna   70000
# 7  Vikash   24  Bangalore   60000

# %%
#Age must be above 23 and city must me "Patna"
df[(df["age"]>23) & (df["city"]=="Patna")]
# Out:
#     name  age   city  salary
# 3   Aman   25  Patna   65000
# 5  Rohit   26  Patna   70000
